# %% [markdown]
# # 📚 PART 1: 대화의 시작 - 컴퓨터와 첫 소통하기
#
# > "프로그래밍은 컴퓨터와의 대화다. 파이썬은 그 대화를 가장 인간답게 만들어준다."
#
# ## 🎯 이 파트에서 배울 내용
#
# 우리는 컴퓨터와 대화하고 싶습니다. 하지만 컴퓨터는 우리 말을 못 알아듣죠.
# 그래서 파이썬이라는 '통역사'가 필요합니다.
#
# 이 파트에서는 컴퓨터와의 **첫 대화**를 시작합니다:
# - 🎤 내가 컴퓨터에게 말하기
# - 🔊 컴퓨터가 나에게 답하기
# - 📝 개발자를 위한 비밀 메모
#
# ---
#
# ## 📖 Chapter 구성
#
# ### [Chapter 1: input() - 내가 컴퓨터에게 말하기](chapter01_input.ipynb)
# - 키보드로 데이터 입력하기
# - input() 함수의 기본 사용법
# - 입력받은 데이터 저장하기
# - **왜 필요한가?** 프로그램과 사용자의 상호작용의 시작점
#
# ### [Chapter 2: print() - 컴퓨터가 나에게 말하기](chapter02_print.ipynb)
# - 화면에 출력하기
# - print() 함수의 다양한 활용
# - 여러 값을 함께 출력하기
# - **왜 필요한가?** 프로그램의 결과를 확인하는 유일한 방법
#
# ### [Chapter 3: logging - 개발자를 위한 비밀 메모](chapter03_logging.ipynb)
# - print()와 logging의 차이
# - 디버깅을 위한 정보 기록
# - 로그 레벨 이해하기
# - **왜 필요한가?** 사용자용 메시지와 개발자용 메시지를 구분
#
# ---
#
# ## 🤔 학습 전 생각해보기
#
# 친구와 대화를 시작할 때를 떠올려보세요:
# 1. 내가 말을 하고 → 친구가 듣고
# 2. 친구가 대답하고 → 내가 듣고
#
# 프로그래밍도 똑같습니다!
# 1. 내가 입력하고 → 컴퓨터가 받고
# 2. 컴퓨터가 출력하고 → 내가 확인하고
#
# ---
#
# ## 💡 학습 팁
#
# 1. **직접 실행해보세요**: 코드는 읽는 것보다 직접 쳐보고 실행하는 것이 중요합니다
# 2. **에러를 두려워하지 마세요**: 에러 메시지도 컴퓨터와의 대화입니다
# 3. **변형해보세요**: 예제 코드를 조금씩 바꿔가며 실험해보세요
#
# ---
#
# ## 🚀 학습 목표
#
# 이 파트를 완료하면:
# - ✅ 사용자로부터 입력을 받을 수 있습니다
# - ✅ 프로그램의 결과를 화면에 출력할 수 있습니다
# - ✅ 간단한 대화형 프로그램을 만들 수 있습니다
# - ✅ 개발 중 디버깅 메시지를 남길 수 있습니다
#
# ---
#
# ## 🎮 미리보기: 이 파트가 끝나면 만들 수 있는 것
#
# ```python
# # 간단한 대화형 프로그램
# print("안녕! 나는 파이썬 봇이야 🤖")
# name = input("너의 이름은 뭐야? ")
# age = input("몇 살이야? ")
# print(f"반가워 {name}! {age}살이구나!")
# print("우리 이제 친구야!")
# ```
#
# ---
#
# ## ➡️ 다음 파트 예고
#
# **문제 상황**: "10"을 입력했는데 10 + 10 = 1010?
# **해결책**: PART 2에서 컴퓨터가 데이터를 이해하는 방식을 배웁니다!
#
# ---
#
# **준비되셨나요? [Chapter 1](chapter01_input.ipynb)부터 시작해봅시다!** 🚀
